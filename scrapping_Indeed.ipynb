# %%
import bs4
from urllib.request import urlopen

# %%
url = 'https://ca.indeed.com/jobs?q=financial+analyst&l=Montr%C3%A9al%2C+QC&ts=1599416790688&rq=1&rsIdx=0'

# %%
html = urlopen(url)
html

# %%
soup = bs4.BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <script src="//d1ewxbznfa539k.cloudfront.net/s/9ae425b/en_CA.js" type="text/javascript"></script>
# <link href="//d1ewxbznfa539k.cloudfront.net/s/b45d10b/jobsearch_all.css" rel="stylesheet" type="text/css"/>
# <link href="https://ca.indeed.com/rss?q=financial+analyst&amp;l=Montr%C3%A9al%2C+QC&amp;radius=25" rel="alternate" title="Financial Analyst Jobs in Montréal, QC" type="application/rss+xml"/>
# <link href="/m/jobs?q=financial+analyst&amp;l=Montr%C3%A9al%2C+QC&amp;radius=25" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="/m/jobs?q=financial+analyst&amp;l=Montr%C3%A9al%2C+QC&amp;radius=25" media="handheld" rel="alternate"/>
# <script type="text/javascript">
#
# if (typeof window['closureReadyCallbacks'] == 'undefined') {
# window['closureReadyCallbacks'] = [];
# }
#
# function call_when_jsall_loaded(cb) {
# ...
